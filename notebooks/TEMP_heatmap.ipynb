# %%
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns


plt.style.use('seaborn')

# %%
run_folder_path = os.path.join(os.path.abspath('../'), 'records', '181902_06032023')

df = pd.DataFrame(columns=['R', 'Rho', 'Value'])

for filename in os.listdir(run_folder_path):
        filename_path = os.path.join(run_folder_path, filename)

        match = re.match(r'r=(\d+\.\d+)_rho=(\d+\.\d+)', filename)
        
        if match is None:
            continue
        
        r = float(match.groups(0)[0])
        rho = float(match.groups(0)[1])
        
        totals_df = pd.read_csv(os.path.join(filename_path, 'totals.csv'))
        value = totals_df.iloc[-1]['Infected']
        
        row = {'R': r, 'Rho': rho, 'Value': value}
        
        new_df = pd.DataFrame([row])
        df = pd.concat([df, new_df], axis=0, ignore_index=True)
        
result = df.pivot(index='R', columns='Rho', values='Value')
ax = sns.heatmap(result, annot=True, cmap=sns.color_palette("Blues", as_cmap=True))

plt.tick_params(axis='both', which='major', labelbottom = False, labeltop=True)
plt.show()

# %%
_run_folder_path = os.path.join(os.path.abspath('../'), 'records', '181902_06032023')

df = pd.DataFrame(columns=['R', 'Rho', 'Value'])

for filename in os.listdir(run_folder_path):
        filename_path = os.path.join(run_folder_path, filename)

        match = re.match(r'r=(\d+\.\d+)_rho=(\d+\.\d+)', filename)
        
        if match is None:
            continue
        
        r = float(match.groups(0)[0])
        rho = float(match.groups(0)[1])
        
        totals_df = pd.read_csv(os.path.join(filename_path, 'totals.csv'))
        value = totals_df.iloc[-1]['Hospitalised']
        
        row = {'R': r, 'Rho': rho, 'Value': value}
        
        new_df = pd.DataFrame([row])
        df = pd.concat([df, new_df], axis=0, ignore_index=True)
        
result = df.pivot(index='R', columns='Rho', values='Value')
ax = sns.heatmap(result, annot=True, cmap=sns.color_palette("Blues", as_cmap=True))

plt.tick_params(axis='both', which='major', labelbottom = False, labeltop=True)
plt.show()

# %%
run_folder_path = os.path.join(os.path.abspath('../'), 'records', '181902_06032023')

df = pd.DataFrame(columns=['R', 'Rho', 'Value'])

for filename in os.listdir(run_folder_path):
        filename_path = os.path.join(run_folder_path, filename)

        match = re.match(r'r=(\d+\.\d+)_rho=(\d+\.\d+)', filename)
        
        if match is None:
            continue
        
        r = float(match.groups(0)[0])
        rho = float(match.groups(0)[1])
        
        totals_df = pd.read_csv(os.path.join(filename_path, 'totals.csv'))
        value = totals_df.iloc[-1]['Dead']
        
        row = {'R': r, 'Rho': rho, 'Value': value}
        
        new_df = pd.DataFrame([row])
        df = pd.concat([df, new_df], axis=0, ignore_index=True)
        
result = df.pivot(index='R', columns='Rho', values='Value')
ax = sns.heatmap(result, annot=True, cmap=sns.color_palette("Blues", as_cmap=True))

plt.tick_params(axis='both', which='major', labelbottom = False, labeltop=True)
plt.show()
